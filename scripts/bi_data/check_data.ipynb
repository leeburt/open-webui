# %%
import pandas as pd 
from chat_data import get_chat_data
pd_data= get_chat_data("../../backend/data/webui.db")
# Out:
# 2025-07-16 08:06:23,887 - INFO - 数据库引擎创建成功。
# 2025-07-16 08:06:23,964 - INFO - 查询成功执行，返回 1125 行。
# 2025-07-16 08:06:23,965 - INFO - 成功读取chat表数据，共 1125 条记录

# %%
pd_data.groupby(['user_name']).count()
# Out:
#              chat_id  chat_user_id  chat_title  chat_model  last_chat_model  \
# user_name
# xuchengba         41            41          41          41               41
# zongyuting-      109           109         109         109              109
# 义政妈               11            11          11          11               11
# 刘桦映                2             2           2           2                2
# 华娟冰                1             1           1           1                1
# 呼呼huhu～           96            96          96          96               96
# 地瓜妈              388           388         388         388              388
# 宋园梦               85            85          85          85               85
# 康复师X壹壹妈          543           543         543         543              543
# 康复师x殷老师           67            67          67          67               67
# 徐畅                61            61          61          61               61
# 徐萍                63            63          63          63               63
# 李园园               73            73          73          73               73
# 杨老师              178           178         178         178              178
# 桐妈                 1             1           1           1                1
# 田文雪               91            91          91          91               91
# 白晓涵              150           150         150         150              150
# 谢老师               13            13          13          13               13
# 邱老师               64            64          64          64               64
#
#              chat_created_at  chat_updated_at  role  model  models  \
# user_name
# xuchengba                 41               41    41      0      41
# zongyuting-              109              109   109      0     109
# 义政妈                       11               11    11      0      11
# 刘桦映                        2                2     2      0       2
# 华娟冰                        1                1     1      0       1
# 呼呼huhu～                   96               96    96      0      96
# 地瓜妈                      388              388   388      0     388
# 宋园梦                       85               85    85      0      85
# 康复师X壹壹妈                  543              543   543      0     543
# 康复师x殷老师                   67               67    67      0      67
# 徐畅                        61               61    61      0      61
# 徐萍                        63               63    63      0      63
# 李园园                       73               73    73      0      73
# 杨老师                      178              178   178      0     178
# 桐妈                         1                1     1      0       1
# 田文雪                       91               91    91      0      91
# 白晓涵                      150              150   150      0     150
# 谢老师                       13               13    13      0      13
# 邱老师                       64               64    64      0      64
#
#              message_id  parentId  last_child_id  childrenIds  created_at  \
# user_name
# xuchengba            41        24             41           41          41
# zongyuting-         109        98            109          109         109
# 义政妈                  11         0             11           11          11
# 刘桦映                   2         0              2            2           2
# 华娟冰                   1         0              1            1           1
# 呼呼huhu～              96         3             96           96          96
# 地瓜妈                 388       111            388          388         388
# 宋园梦                  85        29             85           85          85
# 康复师X壹壹妈             543        76            543          543         543
# 康复师x殷老师              67        57             67           67          67
# 徐畅                   61        58             61           61          61
# 徐萍                   63        57             63           63          63
# 李园园                  73        53             73           73          73
# 杨老师                 178        36            178          178         178
# 桐妈                    1         0              1            1           1
# 田文雪                  91        69             91           91          91
# 白晓涵                 150         4            150          150         150
# 谢老师                  13         9             13           13          13
# 邱老师                  64         0             64           64          64
#
#              content  respond_content
# user_name
# xuchengba         41               41
# zongyuting-      109              109
# 义政妈               11               11
# 刘桦映                2                2
# 华娟冰                1                1
# 呼呼huhu～           96               96
# 地瓜妈              388              388
# 宋园梦               85               85
# 康复师X壹壹妈          543              543
# 康复师x殷老师           67               67
# 徐畅                61               61
# 徐萍                63               63
# 李园园               73               73
# 杨老师              178              178
# 桐妈                 1                1
# 田文雪               91               91
# 白晓涵              150              150
# 谢老师               13               13
# 邱老师               64               64
